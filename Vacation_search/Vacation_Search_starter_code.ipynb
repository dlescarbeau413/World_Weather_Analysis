# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_Database.csv")
city_data_df
# Out:
#      Unnamed: 0          City Country      Lat       Lng  Max Temp  Humidity  \
# 0             0   Tuktoyaktuk      CA  69.4541 -133.0374      6.53        93
# 1             1     Byron Bay      AU -28.6500  153.6167     71.49        85
# 2             2   Mozarlandia      BR -14.7447  -50.5706     77.25        79
# 3             3    Tapiramuta      BR -11.8472  -40.7914     79.14        55
# 4             4       Yakeshi      CN  49.2833  120.7333     16.36        85
# ..          ...           ...     ...      ...       ...       ...       ...
# 701         701  Campos Novos      BR -27.4017  -51.2250     62.11        93
# 702         702        Ikongo      MG -21.8833   47.4333     83.95        50
# 703         703      Aberdeen      GB  57.1437   -2.0981     62.49        66
# 704         704      Brisbane      AU -27.4679  153.0281     73.58        80
# 705         705       Calmeca      MX  18.6333  -98.6333     62.17        59
#
# ...

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum tempurature you would like for your trip?"))
max_temp = float(input("What is the maximum tempurature you would like for you trip?"))
# Out:
# What is the minimum tempurature you would like for your trip?70
# What is the maximum tempurature you would like for you trip?90

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_vaca_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_vaca_df.head(10)
# Out:
#     Unnamed: 0             City Country      Lat       Lng  Max Temp  \
# 1            1        Byron Bay      AU -28.6500  153.6167     71.49
# 2            2      Mozarlandia      BR -14.7447  -50.5706     77.25
# 3            3       Tapiramuta      BR -11.8472  -40.7914     79.14
# 8            8          Rikitea      PF -23.1203 -134.9692     72.36
# 9            9         Hermanus      ZA -34.4187   19.2345     72.90
# 15          15            Alofi      NU -19.0595 -169.9187     76.89
# 16          16          Awjilah      LY  29.1081   21.2869     78.28
# 18          18  Arraial Do Cabo      BR -22.9661  -42.0278     75.16
# 20          20        Inhambane      MZ -23.8650   35.3833     80.58
# 21          21      Capinopolis      BR -18.6819  -49.5697     79.32
#
#     Humidity  Cloudiness  Wind Speed          Current Weather
# 1         85          99       10.60          overcast clouds
# 2         79         100        1.68          overcast clouds
# ...

# %%
# 4a. Determine if there are any empty rows.
preferred_vaca_df.count()
# Out:
# Unnamed: 0         248
# City               248
# Country            247
# Lat                248
# Lng                248
# Max Temp           248
# Humidity           248
# Cloudiness         248
# Wind Speed         248
# Current Weather    248
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
preferred_vaca_spots_df = preferred_vaca_df.dropna()
preferred_vaca_spots_df
# Out:
#      Unnamed: 0            City Country      Lat       Lng  Max Temp  \
# 1             1       Byron Bay      AU -28.6500  153.6167     71.49
# 2             2     Mozarlandia      BR -14.7447  -50.5706     77.25
# 3             3      Tapiramuta      BR -11.8472  -40.7914     79.14
# 8             8         Rikitea      PF -23.1203 -134.9692     72.36
# 9             9        Hermanus      ZA -34.4187   19.2345     72.90
# ..          ...             ...     ...      ...       ...       ...
# 694         694        Umm Lajj      SA  25.0213   37.2685     79.03
# 695         695         Manggar      ID  -2.8833  108.2667     80.19
# 698         698  Nieuw Nickerie      SR   5.9500  -56.9833     82.53
# 702         702          Ikongo      MG -21.8833   47.4333     83.95
# 704         704        Brisbane      AU -27.4679  153.0281     73.58
#
#      Humidity  Cloudiness  Wind Speed  Current Weather
# 1          85          99       10.60  overcast clouds
# ...

# %%
preferred_vaca_spots_df.count()
# Out:
# Unnamed: 0         247
# City               247
# Country            247
# Lat                247
# Lng                247
# Max Temp           247
# Humidity           247
# Cloudiness         247
# Wind Speed         247
# Current Weather    247
# dtype: int64

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_vaca_spots_df[["City", "Country", "Max Temp", "Current Weather", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                City Country  Max Temp          Current Weather      Lat  \
# 1         Byron Bay      AU     71.49          overcast clouds -28.6500
# 2       Mozarlandia      BR     77.25          overcast clouds -14.7447
# 3        Tapiramuta      BR     79.14            broken clouds -11.8472
# 8           Rikitea      PF     72.36                clear sky -23.1203
# 9          Hermanus      ZA     72.90                clear sky -34.4187
# 15            Alofi      NU     76.89                clear sky -19.0595
# 16          Awjilah      LY     78.28                clear sky  29.1081
# 18  Arraial Do Cabo      BR     75.16  light intensity drizzle -22.9661
# 20        Inhambane      MZ     80.58            broken clouds -23.8650
# 21      Capinopolis      BR     79.32          overcast clouds -18.6819
#
#          Lng Hotel Name
# 1   153.6167
# 2   -50.5706
# 3   -40.7914
# 8  -134.9692
# 9    19.2345
# 15 -169.9187
# 16   21.2869
# 18  -42.0278
# 20   35.3833
# 21  -49.5697

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found...skipping the city.")
# Out:
# Hotel not found...skipping the city.
# Hotel not found...skipping the city.
# Hotel not found...skipping the city.
# Hotel not found...skipping the city.
# Hotel not found...skipping the city.
# Hotel not found...skipping the city.
# Hotel not found...skipping the city.
# Hotel not found...skipping the city.
# Hotel not found...skipping the city.
# Hotel not found...skipping the city.
# Hotel not found...skipping the city.
# Hotel not found...skipping the city.

# %%
len(hotels['results'])
# Out:
# 20

# %%
hotel_df
# Out:
#                City Country  Max Temp  Current Weather      Lat       Lng  \
# 1         Byron Bay      AU     71.49  overcast clouds -28.6500  153.6167
# 2       Mozarlandia      BR     77.25  overcast clouds -14.7447  -50.5706
# 3        Tapiramuta      BR     79.14    broken clouds -11.8472  -40.7914
# 8           Rikitea      PF     72.36        clear sky -23.1203 -134.9692
# 9          Hermanus      ZA     72.90        clear sky -34.4187   19.2345
# ..              ...     ...       ...              ...      ...       ...
# 694        Umm Lajj      SA     79.03        clear sky  25.0213   37.2685
# 695         Manggar      ID     80.19  overcast clouds  -2.8833  108.2667
# 698  Nieuw Nickerie      SR     82.53       few clouds   5.9500  -56.9833
# 702          Ikongo      MG     83.95        clear sky -21.8833   47.4333
# 704        Brisbane      AU     73.58        clear sky -27.4679  153.0281
#
#                        Hotel Name
# 1    Backpackers Inn on the Beach
# ...

# %%
# 7. Drop the
clean_hotel_df = hotel_df.dropna(axis="index", how="any")
clean_hotel_df
# Out:
#                City Country  Max Temp  Current Weather      Lat       Lng  \
# 1         Byron Bay      AU     71.49  overcast clouds -28.6500  153.6167
# 2       Mozarlandia      BR     77.25  overcast clouds -14.7447  -50.5706
# 3        Tapiramuta      BR     79.14    broken clouds -11.8472  -40.7914
# 8           Rikitea      PF     72.36        clear sky -23.1203 -134.9692
# 9          Hermanus      ZA     72.90        clear sky -34.4187   19.2345
# ..              ...     ...       ...              ...      ...       ...
# 694        Umm Lajj      SA     79.03        clear sky  25.0213   37.2685
# 695         Manggar      ID     80.19  overcast clouds  -2.8833  108.2667
# 698  Nieuw Nickerie      SR     82.53       few clouds   5.9500  -56.9833
# 702          Ikongo      MG     83.95        clear sky -21.8833   47.4333
# 704        Brisbane      AU     73.58        clear sky -27.4679  153.0281
#
#                        Hotel Name
# 1    Backpackers Inn on the Beach
# ...

# %%
# 8a. Create the output File (CSV)
output_data_file = clean_hotel_df.to_csv("WeatherPy_vacation.csv")
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# 'City_ID,City,Country,Max Temp,Current Weather,Lat,Lng,Hotel Name\r\n1,Byron Bay,AU,71.49,overcast clouds,-28.65,153.6167,Backpackers Inn on the Beach\r\n2,Mozarlandia,BR,77.25,overcast clouds,-14.7447,-50.5706,Hotel Santa Mônica\r\n3,Tapiramuta,BR,79.14,broken clouds,-11.8472,-40.7914,Casa Alencar\r\n8,Rikitea,PF,72.36,clear sky,-23.1203,-134.9692,People ThankYou\r\n9,Hermanus,ZA,72.9,clear sky,-34.4187,19.2345,Misty Waves Boutique Hotel\r\n15,Alofi,NU,76.89,clear sky,-19.0595,-169.9187,Taloa Heights\r\n16,Awjilah,LY,78.28,clear sky,29.1081,21.2869,\r\n18,Arraial Do Cabo,BR,75.16,light intensity drizzle,-22.9661,-42.0278,Pousada Porto Praia\r\n20,Inhambane,MZ,80.58,broken clouds,-23.865,35.3833,Oceano\r\n21,Capinopolis,BR,79.32,overcast clouds,-18.6819,-49.5697,Tropical Hotel\r\n24,Georgetown,MY,84.15,moderate rain,5.4112,100.3354,Cititel Penang\r\n27,Kapaa,US,73.72,broken clouds,22.0752,-159.319,Sheraton Kauai Coconut Beach Resort\r\n31,Grand Gaube,MU,81.0,light rain,-20.0064,57.66
# ...

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Weather}</dd>
<dt>Max Temp</dt><dd>{Max Temp}</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig = gmaps.figure()
fig.add_layer(marker_layer)
fig
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
