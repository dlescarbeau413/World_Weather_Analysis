# %%
import pandas as pd
import random
import numpy as np

# %%
#3.Create a new set of 2,000 random latitudes and longitudes.
#Latitudes
np.random.uniform(-90.000,90.000,size=2000)
# Out:
# array([ 33.3793707 , -16.0379319 , -42.26565559, ..., -86.07629759,
#          7.56015025,  47.47897772])

# %%
#Longitudes

np.random.uniform(-180.000,180.000,size=2000)
# Out:
# array([-50.82986924,  21.71855833, 110.3713067 , ...,  46.85466366,
#        -29.97901612,  15.01562841])

# %%
lats = np.random.uniform(-90.000,90.000,size=2000)
lngs = np.random.uniform(-180.000,180.000,size=2000)
lats_lngs = zip(lats,lngs)
lats_lngs

# %%
coordinates = list(lats_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
import requests

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + "579e5fe230996f4cd59d364a95468f97"

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_conditions = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Weather": city_current_conditions})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tuktoyaktuk
# Processing Record 2 of Set 1 | byron bay
# Processing Record 3 of Set 1 | mozarlandia
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | tapiramuta
# Processing Record 6 of Set 1 | yakeshi
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | lagoa
# Processing Record 9 of Set 1 | burica
# City not found. Skipping...
# Processing Record 10 of Set 1 | fairbanks
# Processing Record 11 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | schagen
# Processing Record 15 of Set 1 | kaitangata
# Processing Record 16 of Set 1 | samdrup jongkhar
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | alofi
# Processing Record 20 of Set 1 | awjilah
# Processing Record 21 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 1 | iqaluit
# Processing Record 23 of Set 1 | arraial do cabo
# Processing Record 24 of Set 1 | dunedin
# Processing Record 25 of Set 1 | inhambane
# Processing Record 26 of Set 1 | capinopolis
# Processing Record 27 of Set 1 | lompoc
# Processing Record 28 of Set 1 | ust-maya
# Processing Record 29 of Set 1 | georgetown
# Processing Record 30 of Set 1 | codrington
# Processing Record 31 of Set 1 | broome
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | vyazemskiy
# Processing Record 34 of Set 1 | bonavista
# Processing Record 35 of Set 1 | taft
# Processing Record 36 of Set 1 | grand gaube
# Processing Record 37 of Set 1 | castro
# Processing Record 38 of Set 1 | faanui
# Processing Record 39 of Set 1 | vostok
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | pevek
# Processing Record 42 of Set 1 | santiago
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | east london
# Processing Record 45 of Set 1 | qaanaaq
# Processing Record 46 of Set 1 | mikhaylovka
# Processing Record 47 of Set 1 | san carlos park
# Processing Record 48 of Set 1 | thompson
# Processing Record 49 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 1 | lebu
# Processing Record 1 of Set 2 | hobart
# Processing Record 2 of Set 2 | chirongui
# Processing Record 3 of Set 2 | jamestown
# Processing Record 4 of Set 2 | cabo san lucas
# Processing Record 5 of Set 2 | jumla
# Processing Record 6 of Set 2 | roald
# Processing Record 7 of Set 2 | airai
# Processing Record 8 of Set 2 | half moon bay
# Processing Record 9 of Set 2 | te anau
# Processing Record 10 of Set 2 | tulun
# Processing Record 11 of Set 2 | chulucanas
# Processing Record 12 of Set 2 | saint george
# Processing Record 13 of Set 2 | tuatapere
# Processing Record 14 of Set 2 | chapais
# Processing Record 15 of Set 2 | oshnaviyeh
# Processing Record 16 of Set 2 | bathsheba
# Processing Record 17 of Set 2 | sorland
# Processing Record 18 of Set 2 | pisco
# Processing Record 19 of Set 2 | victoria
# Processing Record 20 of Set 2 | mahebourg
# Processing Record 21 of Set 2 | omboue
# Processing Record 22 of Set 2 | mataura
# Processing Record 23 of Set 2 | port hardy
# Processing Record 24 of Set 2 | tshikapa
# Processing Record 25 of Set 2 | san patricio
# Processing Record 26 of Set 2 | huntsville
# Processing Record 27 of Set 2 | atuona
# Processing Record 28 of Set 2 | vernon
# Processing Record 29 of Set 2 | kununurra
# Processing Record 30 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 2 | vaini
# Processing Record 32 of Set 2 | talnakh
# Processing Record 33 of Set 2 | aklavik
# Processing Record 34 of Set 2 | cayenne
# Processing Record 35 of Set 2 | tual
# Processing Record 36 of Set 2 | mareeba
# Processing Record 37 of Set 2 | hithadhoo
# Processing Record 38 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 2 | albany
# Processing Record 40 of Set 2 | ust-kuyga
# Processing Record 41 of Set 2 | puerto ayora
# Processing Record 42 of Set 2 | banda aceh
# Processing Record 43 of Set 2 | kem
# Processing Record 44 of Set 2 | new norfolk
# Processing Record 45 of Set 2 | frohnleiten
# Processing Record 46 of Set 2 | longyearbyen
# Processing Record 47 of Set 2 | preobrazheniye
# Processing Record 48 of Set 2 | cape town
# Processing Record 49 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 2 | huarmey
# Processing Record 1 of Set 3 | valparaiso
# Processing Record 2 of Set 3 | saint-philippe
# Processing Record 3 of Set 3 | bethel
# Processing Record 4 of Set 3 | borovoy
# Processing Record 5 of Set 3 | oussouye
# Processing Record 6 of Set 3 | kodiak
# Processing Record 7 of Set 3 | nome
# Processing Record 8 of Set 3 | krasnousolskiy
# City not found. Skipping...
# Processing Record 9 of Set 3 | luganville
# Processing Record 10 of Set 3 | dingle
# Processing Record 11 of Set 3 | misratah
# Processing Record 12 of Set 3 | ponta delgada
# Processing Record 13 of Set 3 | herat
# Processing Record 14 of Set 3 | garm
# City not found. Skipping...
# Processing Record 15 of Set 3 | esperance
# Processing Record 16 of Set 3 | chuy
# Processing Record 17 of Set 3 | torbay
# Processing Record 18 of Set 3 | fukue
# Processing Record 19 of Set 3 | grindavik
# Processing Record 20 of Set 3 | sal rei
# Processing Record 21 of Set 3 | coihaique
# Processing Record 22 of Set 3 | khani
# Processing Record 23 of Set 3 | karlskoga
# Processing Record 24 of Set 3 | mola di bari
# Processing Record 25 of Set 3 | sisimiut
# Processing Record 26 of Set 3 | leningradskiy
# Processing Record 27 of Set 3 | caluquembe
# Processing Record 28 of Set 3 | hilo
# Processing Record 29 of Set 3 | oktyabrskiy
# Processing Record 30 of Set 3 | saint-francois
# Processing Record 31 of Set 3 | jumilla
# Processing Record 32 of Set 3 | cabedelo
# Processing Record 33 of Set 3 | yellowknife
# Processing Record 34 of Set 3 | suffolk
# Processing Record 35 of Set 3 | los algarrobos
# Processing Record 36 of Set 3 | russell
# Processing Record 37 of Set 3 | masvingo
# Processing Record 38 of Set 3 | rio grande
# Processing Record 39 of Set 3 | avarua
# Processing Record 40 of Set 3 | alakurtti
# Processing Record 41 of Set 3 | namatanai
# Processing Record 42 of Set 3 | khatanga
# Processing Record 43 of Set 3 | bengkulu
# Processing Record 44 of Set 3 | kargopol
# Processing Record 45 of Set 3 | tura
# Processing Record 46 of Set 3 | sitka
# Processing Record 47 of Set 3 | fallon
# Processing Record 48 of Set 3 | tiksi
# Processing Record 49 of Set 3 | quang ngai
# Processing Record 50 of Set 3 | bobo dioulasso
# Processing Record 1 of Set 4 | mana
# Processing Record 2 of Set 4 | luba
# Processing Record 3 of Set 4 | hamilton
# Processing Record 4 of Set 4 | wahpeton
# Processing Record 5 of Set 4 | bredasdorp
# Processing Record 6 of Set 4 | neiafu
# Processing Record 7 of Set 4 | eyrarbakki
# Processing Record 8 of Set 4 | wiang sa
# Processing Record 9 of Set 4 | kyra
# Processing Record 10 of Set 4 | dikson
# Processing Record 11 of Set 4 | cururupu
# Processing Record 12 of Set 4 | kahului
# Processing Record 13 of Set 4 | rocha
# Processing Record 14 of Set 4 | imeni zhelyabova
# Processing Record 15 of Set 4 | sioux lookout
# Processing Record 16 of Set 4 | kautokeino
# Processing Record 17 of Set 4 | saratoga springs
# Processing Record 18 of Set 4 | disna
# Processing Record 19 of Set 4 | provideniya
# Processing Record 20 of Set 4 | moree
# Processing Record 21 of Set 4 | mogadishu
# Processing Record 22 of Set 4 | linhares
# Processing Record 23 of Set 4 | chunskiy
# Processing Record 24 of Set 4 | port blair
# Processing Record 25 of Set 4 | port elizabeth
# Processing Record 26 of Set 4 | kutahya
# Processing Record 27 of Set 4 | manokwari
# Processing Record 28 of Set 4 | port-cartier
# Processing Record 29 of Set 4 | trincomalee
# Processing Record 30 of Set 4 | kavaratti
# Processing Record 31 of Set 4 | carnarvon
# Processing Record 32 of Set 4 | kidal
# Processing Record 33 of Set 4 | kawalu
# Processing Record 34 of Set 4 | manyana
# Processing Record 35 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 4 | loudi
# Processing Record 37 of Set 4 | ahipara
# Processing Record 38 of Set 4 | kamaishi
# Processing Record 39 of Set 4 | opuwo
# Processing Record 40 of Set 4 | guia lopes da laguna
# Processing Record 41 of Set 4 | souillac
# Processing Record 42 of Set 4 | odweyne
# Processing Record 43 of Set 4 | hofn
# Processing Record 44 of Set 4 | union
# Processing Record 45 of Set 4 | neuquen
# Processing Record 46 of Set 4 | general pico
# Processing Record 47 of Set 4 | chokurdakh
# Processing Record 48 of Set 4 | ajjampur
# Processing Record 49 of Set 4 | yabrud
# Processing Record 50 of Set 4 | pervomayskoye
# Processing Record 1 of Set 5 | santo andre
# Processing Record 2 of Set 5 | san policarpo
# Processing Record 3 of Set 5 | faya
# Processing Record 4 of Set 5 | stephenville
# Processing Record 5 of Set 5 | brae
# Processing Record 6 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 5 | iquique
# Processing Record 8 of Set 5 | los llanos de aridane
# Processing Record 9 of Set 5 | iowa city
# Processing Record 10 of Set 5 | tursunzoda
# Processing Record 11 of Set 5 | amazar
# Processing Record 12 of Set 5 | chicama
# Processing Record 13 of Set 5 | campbell river
# Processing Record 14 of Set 5 | vao
# Processing Record 15 of Set 5 | dunmore east
# Processing Record 16 of Set 5 | teahupoo
# Processing Record 17 of Set 5 | ende
# Processing Record 18 of Set 5 | sakakah
# Processing Record 19 of Set 5 | adeje
# Processing Record 20 of Set 5 | diamantina
# Processing Record 21 of Set 5 | yerbogachen
# Processing Record 22 of Set 5 | governador valadares
# Processing Record 23 of Set 5 | kangaatsiaq
# Processing Record 24 of Set 5 | laguna
# Processing Record 25 of Set 5 | hokitika
# Processing Record 26 of Set 5 | komsomolskiy
# Processing Record 27 of Set 5 | calvinia
# Processing Record 28 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 5 | mar del plata
# Processing Record 30 of Set 5 | flinders
# Processing Record 31 of Set 5 | krasyliv
# Processing Record 32 of Set 5 | pilibanga
# Processing Record 33 of Set 5 | mombetsu
# Processing Record 34 of Set 5 | kruisfontein
# Processing Record 35 of Set 5 | ribeira grande
# Processing Record 36 of Set 5 | emerald
# Processing Record 37 of Set 5 | roma
# Processing Record 38 of Set 5 | cockburn town
# Processing Record 39 of Set 5 | lensk
# Processing Record 40 of Set 5 | santa cruz
# Processing Record 41 of Set 5 | butaritari
# Processing Record 42 of Set 5 | mandalgovi
# Processing Record 43 of Set 5 | alyangula
# Processing Record 44 of Set 5 | beloha
# Processing Record 45 of Set 5 | caravelas
# Processing Record 46 of Set 5 | tabarqah
# City not found. Skipping...
# Processing Record 47 of Set 5 | garden city
# Processing Record 48 of Set 5 | san carlos de bariloche
# Processing Record 49 of Set 5 | orchard homes
# Processing Record 50 of Set 5 | cairns
# Processing Record 1 of Set 6 | comodoro rivadavia
# Processing Record 2 of Set 6 | salalah
# Processing Record 3 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 4 of Set 6 | bambous virieux
# Processing Record 5 of Set 6 | play cu
# City not found. Skipping...
# Processing Record 6 of Set 6 | songjianghe
# Processing Record 7 of Set 6 | pafos
# Processing Record 8 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 6 | itambacuri
# Processing Record 10 of Set 6 | naze
# Processing Record 11 of Set 6 | khuzdar
# Processing Record 12 of Set 6 | bhanpuri
# Processing Record 13 of Set 6 | hami
# Processing Record 14 of Set 6 | kozyatyn
# Processing Record 15 of Set 6 | henties bay
# Processing Record 16 of Set 6 | kaeo
# Processing Record 17 of Set 6 | taitung
# Processing Record 18 of Set 6 | paamiut
# Processing Record 19 of Set 6 | mudanjiang
# Processing Record 20 of Set 6 | mahdalynivka
# Processing Record 21 of Set 6 | aybak
# City not found. Skipping...
# Processing Record 22 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 6 | grafton
# Processing Record 24 of Set 6 | tasiilaq
# Processing Record 25 of Set 6 | zlatoustovsk
# City not found. Skipping...
# Processing Record 26 of Set 6 | nishihara
# Processing Record 27 of Set 6 | anadyr
# Processing Record 28 of Set 6 | gobabis
# Processing Record 29 of Set 6 | cidreira
# Processing Record 30 of Set 6 | chambery
# Processing Record 31 of Set 6 | hasaki
# Processing Record 32 of Set 6 | husavik
# Processing Record 33 of Set 6 | luderitz
# Processing Record 34 of Set 6 | westport
# Processing Record 35 of Set 6 | bereda
# Processing Record 36 of Set 6 | alta floresta
# Processing Record 37 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 38 of Set 6 | xining
# Processing Record 39 of Set 6 | caruray
# Processing Record 40 of Set 6 | hay river
# Processing Record 41 of Set 6 | mathbaria
# Processing Record 42 of Set 6 | saint anthony
# Processing Record 43 of Set 6 | sinkat
# City not found. Skipping...
# Processing Record 44 of Set 6 | touros
# Processing Record 45 of Set 6 | barrow
# Processing Record 46 of Set 6 | vila velha
# Processing Record 47 of Set 6 | guiyang
# Processing Record 48 of Set 6 | kavieng
# Processing Record 49 of Set 6 | mabaruma
# Processing Record 50 of Set 6 | lavrentiya
# Processing Record 1 of Set 7 | ishikari
# Processing Record 2 of Set 7 | dongsheng
# Processing Record 3 of Set 7 | upernavik
# Processing Record 4 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 7 | nioro
# Processing Record 6 of Set 7 | micheweni
# Processing Record 7 of Set 7 | camacupa
# Processing Record 8 of Set 7 | arawa
# Processing Record 9 of Set 7 | manbij
# Processing Record 10 of Set 7 | ketchikan
# Processing Record 11 of Set 7 | pangkalanbuun
# Processing Record 12 of Set 7 | bandarbeyla
# Processing Record 13 of Set 7 | kamenka
# Processing Record 14 of Set 7 | waingapu
# Processing Record 15 of Set 7 | constitucion
# Processing Record 16 of Set 7 | miraflores
# Processing Record 17 of Set 7 | zavodoukovsk
# Processing Record 18 of Set 7 | manicore
# Processing Record 19 of Set 7 | humaita
# Processing Record 20 of Set 7 | choya
# Processing Record 21 of Set 7 | murindo
# Processing Record 22 of Set 7 | terrasini
# Processing Record 23 of Set 7 | boa vista
# Processing Record 24 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 25 of Set 7 | yatou
# Processing Record 26 of Set 7 | arlit
# Processing Record 27 of Set 7 | yershov
# Processing Record 28 of Set 7 | tongliao
# Processing Record 29 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 30 of Set 7 | bykovo
# Processing Record 31 of Set 7 | sabang
# Processing Record 32 of Set 7 | ossora
# Processing Record 33 of Set 7 | lunavada
# Processing Record 34 of Set 7 | muzhi
# Processing Record 35 of Set 7 | portland
# Processing Record 36 of Set 7 | clyde river
# Processing Record 37 of Set 7 | biak
# Processing Record 38 of Set 7 | orlik
# Processing Record 39 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 40 of Set 7 | berdigestyakh
# Processing Record 41 of Set 7 | sobolevo
# Processing Record 42 of Set 7 | pindiga
# Processing Record 43 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 7 | atar
# Processing Record 45 of Set 7 | san pedro
# Processing Record 46 of Set 7 | tayu
# Processing Record 47 of Set 7 | saskylakh
# Processing Record 48 of Set 7 | port lincoln
# Processing Record 49 of Set 7 | norman wells
# Processing Record 50 of Set 7 | karamay
# City not found. Skipping...
# Processing Record 1 of Set 8 | rovaniemi
# Processing Record 2 of Set 8 | mocuba
# Processing Record 3 of Set 8 | kalawit
# Processing Record 4 of Set 8 | codajas
# Processing Record 5 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 6 of Set 8 | urdoma
# Processing Record 7 of Set 8 | pimentel
# Processing Record 8 of Set 8 | jalu
# Processing Record 9 of Set 8 | ixtapa
# Processing Record 10 of Set 8 | puerto leguizamo
# Processing Record 11 of Set 8 | griffith
# Processing Record 12 of Set 8 | moerai
# Processing Record 13 of Set 8 | lewistown
# Processing Record 14 of Set 8 | kaa-khem
# Processing Record 15 of Set 8 | kupang
# Processing Record 16 of Set 8 | bartlesville
# Processing Record 17 of Set 8 | acapulco
# Processing Record 18 of Set 8 | okhotsk
# Processing Record 19 of Set 8 | conceicao do araguaia
# Processing Record 20 of Set 8 | marsh harbour
# Processing Record 21 of Set 8 | binzhou
# Processing Record 22 of Set 8 | guerrero negro
# Processing Record 23 of Set 8 | hauterive
# Processing Record 24 of Set 8 | kirovsk
# Processing Record 25 of Set 8 | devils lake
# Processing Record 26 of Set 8 | tancheng
# Processing Record 27 of Set 8 | egvekinot
# Processing Record 28 of Set 8 | floro
# Processing Record 29 of Set 8 | narsaq
# Processing Record 30 of Set 8 | yumen
# Processing Record 31 of Set 8 | mutis
# Processing Record 32 of Set 8 | fremont
# Processing Record 33 of Set 8 | kokopo
# Processing Record 34 of Set 8 | solnechnyy
# Processing Record 35 of Set 8 | erenhot
# Processing Record 36 of Set 8 | severo-kurilsk
# Processing Record 37 of Set 8 | novochernorechenskiy
# Processing Record 38 of Set 8 | sokoni
# Processing Record 39 of Set 8 | honiara
# Processing Record 40 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 8 | hobyo
# Processing Record 42 of Set 8 | delcevo
# Processing Record 43 of Set 8 | gudari
# Processing Record 44 of Set 8 | hermon
# Processing Record 45 of Set 8 | katsuura
# Processing Record 46 of Set 8 | ponot
# Processing Record 47 of Set 8 | saldanha
# Processing Record 48 of Set 8 | lamu
# Processing Record 49 of Set 8 | san quintin
# Processing Record 50 of Set 8 | tiarei
# Processing Record 1 of Set 9 | eyl
# Processing Record 2 of Set 9 | ponta do sol
# Processing Record 3 of Set 9 | tooele
# Processing Record 4 of Set 9 | mahbubabad
# Processing Record 5 of Set 9 | san julian
# Processing Record 6 of Set 9 | pochutla
# Processing Record 7 of Set 9 | deputatskiy
# Processing Record 8 of Set 9 | firozpur jhirka
# Processing Record 9 of Set 9 | pemangkat
# Processing Record 10 of Set 9 | karratha
# Processing Record 11 of Set 9 | kozlovo
# Processing Record 12 of Set 9 | domvraina
# Processing Record 13 of Set 9 | nantucket
# Processing Record 14 of Set 9 | revda
# Processing Record 15 of Set 9 | buzmeyin
# Processing Record 16 of Set 9 | umba
# Processing Record 17 of Set 9 | ust-tsilma
# Processing Record 18 of Set 9 | fortuna
# Processing Record 19 of Set 9 | asau
# Processing Record 20 of Set 9 | camacha
# Processing Record 21 of Set 9 | rousinov
# Processing Record 22 of Set 9 | mackay
# Processing Record 23 of Set 9 | emba
# Processing Record 24 of Set 9 | sawtell
# Processing Record 25 of Set 9 | luceville
# City not found. Skipping...
# Processing Record 26 of Set 9 | molepolole
# Processing Record 27 of Set 9 | mala
# Processing Record 28 of Set 9 | nuuk
# Processing Record 29 of Set 9 | yeletskiy
# City not found. Skipping...
# Processing Record 30 of Set 9 | loandjili
# Processing Record 31 of Set 9 | maarianhamina
# Processing Record 32 of Set 9 | gallup
# Processing Record 33 of Set 9 | takoradi
# Processing Record 34 of Set 9 | saleilua
# City not found. Skipping...
# Processing Record 35 of Set 9 | kieta
# Processing Record 36 of Set 9 | barmer
# Processing Record 37 of Set 9 | sao filipe
# Processing Record 38 of Set 9 | hammerfest
# Processing Record 39 of Set 9 | reconquista
# Processing Record 40 of Set 9 | mweka
# Processing Record 41 of Set 9 | mabama
# Processing Record 42 of Set 9 | mount gambier
# Processing Record 43 of Set 9 | gwadar
# Processing Record 44 of Set 9 | belyy yar
# Processing Record 45 of Set 9 | aksu
# Processing Record 46 of Set 9 | varzea da palma
# Processing Record 47 of Set 9 | berlevag
# Processing Record 48 of Set 9 | guangyuan
# Processing Record 49 of Set 9 | camana
# Processing Record 50 of Set 9 | kutum
# Processing Record 1 of Set 10 | atbasar
# Processing Record 2 of Set 10 | carauari
# Processing Record 3 of Set 10 | ancud
# Processing Record 4 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 10 | cherskiy
# Processing Record 6 of Set 10 | ulladulla
# Processing Record 7 of Set 10 | shingu
# Processing Record 8 of Set 10 | fairfield
# Processing Record 9 of Set 10 | hualmay
# Processing Record 10 of Set 10 | lashio
# Processing Record 11 of Set 10 | abengourou
# Processing Record 12 of Set 10 | port shepstone
# Processing Record 13 of Set 10 | valkeakoski
# Processing Record 14 of Set 10 | campo maior
# Processing Record 15 of Set 10 | coquimbo
# Processing Record 16 of Set 10 | loralai
# Processing Record 17 of Set 10 | benalla
# Processing Record 18 of Set 10 | nurota
# Processing Record 19 of Set 10 | opochka
# Processing Record 20 of Set 10 | lumding
# Processing Record 21 of Set 10 | ilulissat
# Processing Record 22 of Set 10 | lafiagi
# Processing Record 23 of Set 10 | whitehorse
# Processing Record 24 of Set 10 | channel-port aux basques
# Processing Record 25 of Set 10 | gigmoto
# Processing Record 26 of Set 10 | labuhan
# Processing Record 27 of Set 10 | pascagoula
# Processing Record 28 of Set 10 | northam
# Processing Record 29 of Set 10 | tezu
# Processing Record 30 of Set 10 | pajapan
# Processing Record 31 of Set 10 | sao felix do xingu
# Processing Record 32 of Set 10 | iwanai
# Processing Record 33 of Set 10 | tortoli
# Processing Record 34 of Set 10 | ponnani
# Processing Record 35 of Set 10 | klaksvik
# Processing Record 36 of Set 10 | vanavara
# Processing Record 37 of Set 10 | texarkana
# Processing Record 38 of Set 10 | walvis bay
# Processing Record 39 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 10 | mukhen
# Processing Record 41 of Set 10 | cerritos
# Processing Record 42 of Set 10 | general jose eduvigis diaz
# Processing Record 43 of Set 10 | corrente
# Processing Record 44 of Set 10 | lucapa
# Processing Record 45 of Set 10 | meulaboh
# Processing Record 46 of Set 10 | lake city
# Processing Record 47 of Set 10 | moron
# Processing Record 48 of Set 10 | malanje
# Processing Record 49 of Set 10 | trapani
# Processing Record 50 of Set 10 | stirling
# Processing Record 1 of Set 11 | kudahuvadhoo
# Processing Record 2 of Set 11 | udarnyy
# Processing Record 3 of Set 11 | taoudenni
# Processing Record 4 of Set 11 | ignatovka
# Processing Record 5 of Set 11 | caborca
# Processing Record 6 of Set 11 | ziarat
# Processing Record 7 of Set 11 | bar harbor
# Processing Record 8 of Set 11 | mehamn
# Processing Record 9 of Set 11 | sibolga
# Processing Record 10 of Set 11 | angra
# City not found. Skipping...
# Processing Record 11 of Set 11 | aitape
# Processing Record 12 of Set 11 | pryozerne
# Processing Record 13 of Set 11 | dhidhdhoo
# Processing Record 14 of Set 11 | inta
# Processing Record 15 of Set 11 | teuchitlan
# Processing Record 16 of Set 11 | bocas del toro
# Processing Record 17 of Set 11 | naryan-mar
# Processing Record 18 of Set 11 | sterling
# Processing Record 19 of Set 11 | louga
# Processing Record 20 of Set 11 | mandla
# Processing Record 21 of Set 11 | olafsvik
# Processing Record 22 of Set 11 | ngunguru
# Processing Record 23 of Set 11 | broken hill
# Processing Record 24 of Set 11 | zhanaozen
# Processing Record 25 of Set 11 | ippy
# Processing Record 26 of Set 11 | batemans bay
# Processing Record 27 of Set 11 | temirgoyevskaya
# Processing Record 28 of Set 11 | nova olimpia
# Processing Record 29 of Set 11 | zhigansk
# Processing Record 30 of Set 11 | pontianak
# Processing Record 31 of Set 11 | makakilo city
# Processing Record 32 of Set 11 | sarangani
# Processing Record 33 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 34 of Set 11 | ostrovnoy
# Processing Record 35 of Set 11 | lubango
# Processing Record 36 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 11 | winnemucca
# Processing Record 38 of Set 11 | maragogi
# Processing Record 39 of Set 11 | taua
# Processing Record 40 of Set 11 | uruzgan
# Processing Record 41 of Set 11 | harper
# Processing Record 42 of Set 11 | maraa
# Processing Record 43 of Set 11 | teramo
# Processing Record 44 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 45 of Set 11 | kaseda
# Processing Record 46 of Set 11 | karpathos
# Processing Record 47 of Set 11 | bambanglipuro
# Processing Record 48 of Set 11 | inirida
# Processing Record 49 of Set 11 | havre-saint-pierre
# Processing Record 50 of Set 11 | pacific grove
# Processing Record 1 of Set 12 | tucuman
# Processing Record 2 of Set 12 | margate
# Processing Record 3 of Set 12 | kungurtug
# Processing Record 4 of Set 12 | maumere
# Processing Record 5 of Set 12 | alugan
# Processing Record 6 of Set 12 | simao
# Processing Record 7 of Set 12 | owando
# Processing Record 8 of Set 12 | bose
# Processing Record 9 of Set 12 | soe
# Processing Record 10 of Set 12 | pandrup
# Processing Record 11 of Set 12 | lazurne
# Processing Record 12 of Set 12 | victor harbor
# Processing Record 13 of Set 12 | vestmanna
# Processing Record 14 of Set 12 | panzhihua
# Processing Record 15 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 16 of Set 12 | vorobyevka
# Processing Record 17 of Set 12 | cusco
# Processing Record 18 of Set 12 | tabas
# Processing Record 19 of Set 12 | ust-nera
# Processing Record 20 of Set 12 | germantown
# Processing Record 21 of Set 12 | pahrump
# Processing Record 22 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 23 of Set 12 | bouca
# Processing Record 24 of Set 12 | bilibino
# Processing Record 25 of Set 12 | bairiki
# Processing Record 26 of Set 12 | caxias do sul
# Processing Record 27 of Set 12 | nuevo progreso
# Processing Record 28 of Set 12 | esmeralda
# Processing Record 29 of Set 12 | peterborough
# Processing Record 30 of Set 12 | sinjar
# Processing Record 31 of Set 12 | colonial park
# Processing Record 32 of Set 12 | upata
# Processing Record 33 of Set 12 | lagos
# Processing Record 34 of Set 12 | la oroya
# Processing Record 35 of Set 12 | beringovskiy
# Processing Record 36 of Set 12 | atherton
# Processing Record 37 of Set 12 | morondava
# Processing Record 38 of Set 12 | magadan
# Processing Record 39 of Set 12 | port-gentil
# Processing Record 40 of Set 12 | luanda
# Processing Record 41 of Set 12 | ayagoz
# Processing Record 42 of Set 12 | fuerte olimpo
# Processing Record 43 of Set 12 | richards bay
# Processing Record 44 of Set 12 | kande
# Processing Record 45 of Set 12 | yantal
# Processing Record 46 of Set 12 | ukiah
# Processing Record 47 of Set 12 | shu
# Processing Record 48 of Set 12 | palauig
# Processing Record 49 of Set 12 | longonjo
# Processing Record 50 of Set 12 | port augusta
# Processing Record 1 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 2 of Set 13 | tabuk
# Processing Record 3 of Set 13 | pangnirtung
# Processing Record 4 of Set 13 | sur
# Processing Record 5 of Set 13 | buala
# Processing Record 6 of Set 13 | viedma
# Processing Record 7 of Set 13 | eureka
# Processing Record 8 of Set 13 | moose factory
# Processing Record 9 of Set 13 | nosy varika
# Processing Record 10 of Set 13 | tynda
# Processing Record 11 of Set 13 | inverell
# Processing Record 12 of Set 13 | bowen
# Processing Record 13 of Set 13 | san anselmo
# Processing Record 14 of Set 13 | kirs
# Processing Record 15 of Set 13 | novikovo
# Processing Record 16 of Set 13 | sao miguel do araguaia
# Processing Record 17 of Set 13 | barahona
# Processing Record 18 of Set 13 | boueni
# Processing Record 19 of Set 13 | yinchuan
# Processing Record 20 of Set 13 | tecoanapa
# Processing Record 21 of Set 13 | cascais
# Processing Record 22 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 13 | alihe
# Processing Record 24 of Set 13 | nikolskoye
# Processing Record 25 of Set 13 | wuan
# Processing Record 26 of Set 13 | poum
# Processing Record 27 of Set 13 | kandrian
# Processing Record 28 of Set 13 | bubaque
# Processing Record 29 of Set 13 | reidsville
# Processing Record 30 of Set 13 | kyshtovka
# Processing Record 31 of Set 13 | san cristobal
# Processing Record 32 of Set 13 | kijabe
# Processing Record 33 of Set 13 | north bend
# Processing Record 34 of Set 13 | gorontalo
# Processing Record 35 of Set 13 | mali
# Processing Record 36 of Set 13 | shakawe
# Processing Record 37 of Set 13 | bonthe
# Processing Record 38 of Set 13 | kambove
# Processing Record 39 of Set 13 | necochea
# Processing Record 40 of Set 13 | yanchukan
# City not found. Skipping...
# Processing Record 41 of Set 13 | duncan
# Processing Record 42 of Set 13 | sinfra
# Processing Record 43 of Set 13 | benton
# Processing Record 44 of Set 13 | ust-karsk
# Processing Record 45 of Set 13 | muros
# Processing Record 46 of Set 13 | charagua
# Processing Record 47 of Set 13 | znamenskoye
# Processing Record 48 of Set 13 | avera
# Processing Record 49 of Set 13 | key west
# Processing Record 50 of Set 13 | wote
# Processing Record 1 of Set 14 | ouadda
# Processing Record 2 of Set 14 | venustiano carranza
# Processing Record 3 of Set 14 | litoral del san juan
# City not found. Skipping...
# Processing Record 4 of Set 14 | vanimo
# Processing Record 5 of Set 14 | tessalit
# Processing Record 6 of Set 14 | lorengau
# Processing Record 7 of Set 14 | garden acres
# Processing Record 8 of Set 14 | santa maria
# Processing Record 9 of Set 14 | mucurapo
# Processing Record 10 of Set 14 | nenjiang
# Processing Record 11 of Set 14 | kursumlija
# Processing Record 12 of Set 14 | saint-augustin
# Processing Record 13 of Set 14 | ternate
# Processing Record 14 of Set 14 | san vicente
# Processing Record 15 of Set 14 | darhan
# Processing Record 16 of Set 14 | chumikan
# Processing Record 17 of Set 14 | khor
# Processing Record 18 of Set 14 | shelburne
# Processing Record 19 of Set 14 | soyo
# Processing Record 20 of Set 14 | itarare
# Processing Record 21 of Set 14 | sahuaripa
# Processing Record 22 of Set 14 | colesberg
# Processing Record 23 of Set 14 | tikapur
# Processing Record 24 of Set 14 | fez
# Processing Record 25 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 26 of Set 14 | angoche
# Processing Record 27 of Set 14 | praya
# Processing Record 28 of Set 14 | kirakira
# Processing Record 29 of Set 14 | kapoeta
# Processing Record 30 of Set 14 | one hundred mile house
# City not found. Skipping...
# Processing Record 31 of Set 14 | port hedland
# Processing Record 32 of Set 14 | srednekolymsk
# Processing Record 33 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 34 of Set 14 | pembroke
# Processing Record 35 of Set 14 | rio gallegos
# Processing Record 36 of Set 14 | gat
# Processing Record 37 of Set 14 | heilbron
# Processing Record 38 of Set 14 | inca
# Processing Record 39 of Set 14 | mecca
# Processing Record 40 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 41 of Set 14 | zyryanskoye
# Processing Record 42 of Set 14 | coahuayana
# Processing Record 43 of Set 14 | vila franca do campo
# Processing Record 44 of Set 14 | alice springs
# Processing Record 45 of Set 14 | dudinka
# Processing Record 46 of Set 14 | nanortalik
# Processing Record 47 of Set 14 | usinsk
# Processing Record 48 of Set 14 | tazovskiy
# Processing Record 49 of Set 14 | ambon
# Processing Record 50 of Set 14 | zyryanka
# Processing Record 1 of Set 15 | senanga
# Processing Record 2 of Set 15 | panguna
# Processing Record 3 of Set 15 | mosquera
# Processing Record 4 of Set 15 | sinnamary
# Processing Record 5 of Set 15 | susanville
# Processing Record 6 of Set 15 | tres arroyos
# Processing Record 7 of Set 15 | puerto el triunfo
# Processing Record 8 of Set 15 | pitimbu
# Processing Record 9 of Set 15 | turukhansk
# Processing Record 10 of Set 15 | gwanda
# Processing Record 11 of Set 15 | kirensk
# Processing Record 12 of Set 15 | dong hoi
# Processing Record 13 of Set 15 | bulgan
# Processing Record 14 of Set 15 | kasane
# Processing Record 15 of Set 15 | saint-pierre
# Processing Record 16 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 15 | loreto
# Processing Record 18 of Set 15 | tres lagoas
# Processing Record 19 of Set 15 | charlestown
# Processing Record 20 of Set 15 | siuri
# Processing Record 21 of Set 15 | katha
# City not found. Skipping...
# Processing Record 22 of Set 15 | yulara
# Processing Record 23 of Set 15 | sikasso
# Processing Record 24 of Set 15 | amuntai
# Processing Record 25 of Set 15 | posse
# Processing Record 26 of Set 15 | shimoda
# Processing Record 27 of Set 15 | markova
# Processing Record 28 of Set 15 | makarska
# Processing Record 29 of Set 15 | chico
# Processing Record 30 of Set 15 | lastoursville
# Processing Record 31 of Set 15 | svetlogorsk
# Processing Record 32 of Set 15 | kalmunai
# Processing Record 33 of Set 15 | urubicha
# Processing Record 34 of Set 15 | awbari
# Processing Record 35 of Set 15 | togitsu
# Processing Record 36 of Set 15 | zhezkazgan
# Processing Record 37 of Set 15 | shumikha
# Processing Record 38 of Set 15 | jawhar
# Processing Record 39 of Set 15 | evensk
# Processing Record 40 of Set 15 | jujuy
# City not found. Skipping...
# Processing Record 41 of Set 15 | juneau
# Processing Record 42 of Set 15 | iquitos
# Processing Record 43 of Set 15 | sorong
# Processing Record 44 of Set 15 | shar
# Processing Record 45 of Set 15 | presidencia roque saenz pena
# Processing Record 46 of Set 15 | umm lajj
# Processing Record 47 of Set 15 | manggar
# Processing Record 48 of Set 15 | estacion coahuila
# Processing Record 49 of Set 15 | pierre
# Processing Record 50 of Set 15 | nieuw nickerie
# Processing Record 1 of Set 16 | natal
# Processing Record 2 of Set 16 | rafraf
# Processing Record 3 of Set 16 | campos novos
# Processing Record 4 of Set 16 | ikongo
# Processing Record 5 of Set 16 | aberdeen
# Processing Record 6 of Set 16 | brisbane
# Processing Record 7 of Set 16 | calmeca
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 706

# %%
city_weather_df = pd.DataFrame(city_data)
city_weather_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Tuktoyaktuk  69.4541 -133.0374      6.53        93         100       19.75
# 1    Byron Bay -28.6500  153.6167     71.49        85          99       10.60
# 2  Mozarlandia -14.7447  -50.5706     77.25        79         100        1.68
# 3   Tapiramuta -11.8472  -40.7914     79.14        55          73        5.59
# 4      Yakeshi  49.2833  120.7333     16.36        85         100        2.01
# 5  Port Alfred -33.5906   26.8910     67.30        65          47       17.72
# 6        Lagoa  39.0500  -27.9833     65.23        73         100       20.76
# 7    Fairbanks  64.8378 -147.7164     -6.09        74           1        0.00
# 8      Rikitea -23.1203 -134.9692     72.36        66           9        8.63
# 9     Hermanus -34.4187   19.2345     72.90        59           0       14.32
#
#   Country   Current Weather
# 0      CA   overcast clouds
# 1      AU   overcast clouds
# 2      BR   overcast clouds
# 3      BR     broken clouds
# 4      CN   overcast clouds
# 5      ZA  scattered clouds
# 6      PT   overcast clouds
# 7      US              mist
# 8      PF         clear sky
# 9      ZA         clear sky

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Weather"]

city_weather_df = city_weather_df[new_column_order]

# %%
city_weather_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Tuktoyaktuk      CA  69.4541 -133.0374      6.53        93         100
# 1    Byron Bay      AU -28.6500  153.6167     71.49        85          99
# 2  Mozarlandia      BR -14.7447  -50.5706     77.25        79         100
# 3   Tapiramuta      BR -11.8472  -40.7914     79.14        55          73
# 4      Yakeshi      CN  49.2833  120.7333     16.36        85         100
# 5  Port Alfred      ZA -33.5906   26.8910     67.30        65          47
# 6        Lagoa      PT  39.0500  -27.9833     65.23        73         100
# 7    Fairbanks      US  64.8378 -147.7164     -6.09        74           1
# 8      Rikitea      PF -23.1203 -134.9692     72.36        66           9
# 9     Hermanus      ZA -34.4187   19.2345     72.90        59           0
#
#    Wind Speed   Current Weather
# 0       19.75   overcast clouds
# 1       10.60   overcast clouds
# 2        1.68   overcast clouds
# 3        5.59     broken clouds
# 4        2.01   overcast clouds
# 5       17.72  scattered clouds
# 6       20.76   overcast clouds
# 7        0.00              mist
# 8        8.63         clear sky
# 9       14.32         clear sky

# %%
city_weather_df.to_csv("WeatherPy_Database.csv")
